# %% [markdown]
# # 파일 설명
#
# * 조석 예보 크롤링 파일
# * 실행은 '실행부' section에서 진행해주시기 바랍니다.

# %% [markdown]
# # API 정보 설명

# %% [markdown]
# * 해양수산부 조석 예보 API : http://www.khoa.go.kr/oceangrid/khoa/takepart/openapi/openApiObsTidePreTabDataInfo.do
#
# * 관측소 정보 : /milsul_Obs.csv
#
# ![image.png](attachment:0c4720e8-dd03-474f-b615-a439fc4f7f6b.png)

# %% [markdown]
# # 기본 import

# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster
from folium import plugins
from folium.features import CustomIcon

# %% [markdown]
# # 함수 선언부

# %%
# (1) 밀물썰물 json 파일 크롤링 함수
def milsul_crawling(Date, ObsCode, ResultType):

    '''
    * 함수 소개
    기상청 API로부터 기상 예보 불러오기
    반환 데이터 : JSON 파일
    
    * 파라미터 소개
    (1) Date : 검색 기준 날짜 / YYYYMMDD / str
    (2) ObsCode : 관측소 번호 / str
    (3) ResultType : 결과 타입 / json or xml / str
    
    * 주요 키값
    (1) obs_post_id : 고정 관측소 ID
    (2) obs_post_name : 고정 관측소 명
    (3) obs_lat : 관측소 위도
    (4) obs_lon : 관측소 경도
    (5) hl_code : 저조, 고조 구분
    (6) tph_time : 극치 시간
    (7) tph_level : 극치 값 (단위 : cm)
    (8) obs_last_req_cnt : 금일요청가능횟수 (남은요청수/할당요청수)
    
    * 사용 예시
    forecast('20221122', '0200', '60', '127')
    '''
    # 사용할 라이브러리 import
    import requests
    import json
    
    # 기본 정보 변수에 할당
    DataType = 'tideObsPreTab'
    ServiceKey = 'ir2MEaj6OM7hzsVQmxWiTQ=='
    ObsCode = ObsCode
    
    # 크롤링에 필요한 url과 파라미터들 정의
    url = str('https://www.khoa.go.kr/api/oceangrid/' + DataType + '/search.do?')
    params = {'DataType' : DataType, 'ServiceKey' : ServiceKey, 'ObsCode' : ObsCode, 'Date' : Date, 'ResultType' : ResultType}
    
    ## 데이터 응답
    response = requests.get(url, params=params)
    
    ## 리턴값 : json 파일
    return response.json()

# %%
# (2) 모든 관측소 자료 불러오기 함수

def milsul_crawling_all(date):
    
    # (1)import와 (2)기본 크롤링 함수 사용 위한 파라미터 정의
    import pandas as pd
    ResultType = 'json'
    
    # 관측소 정보 파일 불러오기
    df = pd.read_csv('milsul_Obs.csv', encoding='cp949')
    
    # 알림 메세지
    print("데이터 수집을 시작합니다. 시간이 5분 가량 소요됩니다.")
    pd.set_option('mode.chained_assignment',  None)
    
    # Date에 맞는 밀물 썰물 데이터 받아오기
    for i in range(len(df['관측소 번호'])):
        
        print(f"({i+1}/{len(df['관측소 번호'])+1}) {df['관측소 번호'][i]} {df['관측소 명'][i]} 데이터 수집")
        
        obscode = df['관측소 번호'][i]
        df['Date'][i] = date
        data = milsul_crawling(date, obscode, ResultType).get('result').get('data')
        
        for j in range(4):
            try:
                df['tph_level_' + str(j+1)][i] = data[j].get('tph_level')
                df['tph_time_' + str(j+1)][i] = data[j].get('tph_time')
                df['hl_code_' + str(j+1)][i] = data[j].get('hl_code')
                
            except:
                print('#######', df['관측소 번호'][i], df['관측소 명'][i], '데이터가 없습니다.')
                continue

    return df

# %% [markdown]
# # 실행 부

# %%
date = input("날짜를 입력해주세요 (YYYYMMDD)")
df = milsul_crawling_all(date)

set1 = df[['관측소 번호', '관측소 명', '위도', '경도', 'Date', 'hl_code_1', 'tph_time_1', 'tph_level_1']]
set2 = df[['관측소 번호', '관측소 명', '위도', '경도', 'Date', 'hl_code_2', 'tph_time_2', 'tph_level_2']]
set3 = df[['관측소 번호', '관측소 명', '위도', '경도', 'Date', 'hl_code_3', 'tph_time_3', 'tph_level_3']]

set1.columns = ['관측소 번호', '관측소 명', '위도', '경도', 'Date', 'tph_level', 'tph_time', 'hl_code']
set2.columns = ['관측소 번호', '관측소 명', '위도', '경도', 'Date', 'tph_level', 'tph_time', 'hl_code']
set3.columns = ['관측소 번호', '관측소 명', '위도', '경도', 'Date', 'tph_level', 'tph_time', 'hl_code']

df2 = pd.concat([pd.concat([set1, set2], axis=0), set3], axis=0)
# Out:
# 날짜를 입력해주세요 (YYYYMMDD) 20221201
# 데이터 수집을 시작합니다. 시간이 5분 가량 소요됩니다.
# (1/145) SO_0732 남애항 데이터 수집
# (2/145) SO_0733 강릉항 데이터 수집
# (3/145) SO_0734 궁촌항 데이터 수집
# (4/145) SO_0735 죽변항 데이터 수집
# ####### SO_0735 죽변항 데이터가 없습니다.
# (5/145) SO_0736 축산항 데이터 수집
# ####### SO_0736 축산항 데이터가 없습니다.
# ####### SO_0736 축산항 데이터가 없습니다.
# (6/145) SO_0737 강구항 데이터 수집
# (7/145) SO_0555 서망항 데이터 수집
# ####### SO_0555 서망항 데이터가 없습니다.
# (8/145) SO_0739 도장항 데이터 수집
# (9/145) SO_0740 보옥항 데이터 수집
# ####### SO_0740 보옥항 데이터가 없습니다.
# (10/145) SO_0699 천리포항 데이터 수집
# (11/145) SO_0562 승봉도 데이터 수집
# (12/145) SO_0573 양포항 데이터 수집
# ####### SO_0573 양포항 데이터가 없습니다.
# ####### SO_0573 양포항 데이터가 없습니다.
# (13/145) SO_0581 강양항 데이터 수집
# (14/145) SO_0571 거제외포 데이터 수집
# (15/145) SO_0578 소매물도 데이터 수집
# (16/145) SO_0567 쉬미항 데이터 수집
# (17/145) SO_0576 화봉리 데이터 수집
# (18/145) SO_0564 국화도 데이터 수집
# (19/145) SO_0563 울도 데이터 수집
# (20/145) SO_0706 청산도 데이터 수집
# (21/145) SO_0708 안도항 데이터 수집
# (22/145) SO_0712 능양항 데이터 수집
# (23/145) SO_0701 홍도항 데이터 수집
# (24/145) SO_0702 진도옥도 데이터 수집
# (25/145) SO_0703 땅끝항 데이터 수집
# ####### SO_0703 땅끝항 데이터가 없습니다.
# (26/145) SO_0704 소안항 데이터 수집
# ####### SO_0704 소안항 데이터가 없습니다.
# (27/145) DT_0040 독도 데이터 수집
# (28/145) DT_0002 평택 데이터 수집
# (29/145) DT_0003 영광 데이터 수집
# (30/145) DT_0004 제주 데이터 수집
# ####### DT_0004 제주 데이터가 없습니다.
# (31/145) DT_0005 부산 데이터 수집
# (32/145) DT_0006 묵호 데이터 수집
# (33/145) DT_0007 목포 데이터 수집
# (34/145) DT_0008 안산 데이터 수집
# (35/145) DT_0010 서귀포 데이터 수집
# (36/145) DT_0011 후포 데이터 수집
# ####### DT_0011 후포 데이터가 없습니다.
# (37/145) DT_0012 속초 데이터 수집
# (38/145) DT_0013 울릉도 데이터 수집
# (39/145) DT_0016 여수 데이터 수집
# (40/145) DT_0017 대산 데이터 수집
# (41/145) DT_0018 군산 데이터 수집
# (42/145) DT_0021 추자도 데이터 수집
# ####### DT_0021 추자도 데이터가 없습니다.
# (43/145) DT_0023 모슬포 데이터 수집
# (44/145) DT_0028 진도 데이터 수집
# ####### DT_0028 진도 데이터가 없습니다.
# (45/145) DT_0032 강화대교 데이터 수집
# ####### DT_0032 강화대교 데이터가 없습니다.
# (46/145) SO_0553 해운대 데이터 수집
# (47/145) SO_0540 호산항 데이터 수집
# (48/145) DT_0020 울산 데이터 수집
# (49/145) DT_0022 성산포 데이터 수집
# (50/145) DT_0024 장항 데이터 수집
# (51/145) DT_0026 고흥발포 데이터 수집
# (52/145) DT_0027 완도 데이터 수집
# (53/145) DT_0029 거제도 데이터 수집
# (54/145) DT_0031 거문도 데이터 수집
# (55/145) DT_0035 흑산도 데이터 수집
# (56/145) DT_0044 영종대교 데이터 수집
# (57/145) DT_0047 도농탄 데이터 수집
# (58/145) DT_0050 태안 데이터 수집
# (59/145) DT_0048 속초등표 데이터 수집
# (60/145) DT_0051 서천마량 데이터 수집
# (61/145) SO_0549 초도 데이터 수집
# (62/145) DT_0049 광양 데이터 수집
# (63/145) DT_0056 부산항신항 데이터 수집
# (64/145) DT_0057 동해항 데이터 수집
# (65/145) SO_0538 안마도 데이터 수집
# (66/145) SO_0539 강화외포 데이터 수집
# (67/145) DT_0058 경인항 데이터 수집
# (68/145) SO_0554 영종왕산 데이터 수집
# (69/145) SO_0326 미조항 데이터 수집
# (70/145) IE_0060 이어도 데이터 수집
# ####### IE_0060 이어도 데이터가 없습니다.
# (71/145) DT_0038 굴업도 데이터 수집
# (72/145) DT_0025 보령 데이터 수집
# (73/145) DT_0001 인천 데이터 수집
# (74/145) DT_0052 인천송도 데이터 수집
# (75/145) DT_0014 통영 데이터 수집
# (76/145) DT_0037 어청도 데이터 수집
# (77/145) DT_0046 쌍정초 데이터 수집
# (78/145) DT_0039 왕돌초 데이터 수집
# (79/145) DT_0041 복사초 데이터 수집
# ####### DT_0041 복사초 데이터가 없습니다.
# (80/145) DT_0042 교본초 데이터 수집
# (81/145) DT_0043 영흥도 데이터 수집
# (82/145) DT_0061 삼천포 데이터 수집
# (83/145) SO_0537 벽파진 데이터 수집
# ####### SO_0537 벽파진 데이터가 없습니다.
# (84/145) SO_0536 덕적도 데이터 수집
# (85/145) SO_0547 말도 데이터 수집
# (86/145) SO_0550 나로도 데이터 수집
# (87/145) SO_0705 마량항 데이터 수집
# (88/145) SO_0707 시산항 데이터 수집
# (89/145) SO_0709 두문포 데이터 수집
# (90/145) SO_0710 봉우항 데이터 수집
# (91/145) SO_0711 창선도 데이터 수집
# (92/145) SO_0700 호도 데이터 수집
# (93/145) SO_0551 여서도 데이터 수집
# (94/145) DT_0901 포항_구 데이터 수집
# ####### DT_0901 포항_구 데이터가 없습니다.
# ####### DT_0901 포항_구 데이터가 없습니다.
# (95/145) SO_0552 고현항 데이터 수집
# (96/145) IE_0062 옹진소청초 데이터 수집
# (97/145) IE_0061 신안가거초 데이터 수집
# (98/145) SO_0543 서거차도 데이터 수집
# ####### SO_0543 서거차도 데이터가 없습니다.
# (99/145) SO_0548 우이도 데이터 수집
# (100/145) SO_0572 읍천항 데이터 수집
# (101/145) SO_0569 남포항 데이터 수집
# (102/145) SO_0570 광암항 데이터 수집
# (103/145) SO_0568 백야도 데이터 수집
# (104/145) SO_0577 가거도 데이터 수집
# (105/145) SO_0566 송공항 데이터 수집
# (106/145) SO_0565 향화도항 데이터 수집
# (107/145) SO_0574 백사장항 데이터 수집
# (108/145) SO_0731 대진항 데이터 수집
# (109/145) SO_1251 낙월도 데이터 수집
# (110/145) SO_1252 외연도항 데이터 수집
# (111/145) SO_0757 안남리 데이터 수집
# (112/145) SO_0755 원동항 데이터 수집
# (113/145) SO_0754 평호리 데이터 수집
# ####### SO_0754 평호리 데이터가 없습니다.
# (114/145) SO_1256 어류정항 데이터 수집
# (115/145) SO_1249 독거도 데이터 수집
# ####### SO_1249 독거도 데이터가 없습니다.
# (116/145) SO_1250 평도 데이터 수집
# (117/145) SO_1253 상왕등도 데이터 수집
# (118/145) SO_1254 만재도 데이터 수집
# (119/145) SO_1248 신안옥도 데이터 수집
# (120/145) SO_0759 장문리 데이터 수집
# (121/145) DT_0068 위도 데이터 수집
# (122/145) SO_0760 오산항 데이터 수집
# (123/145) SO_0753 하의도웅곡 데이터 수집
# (124/145) SO_0631 암태도 데이터 수집
# (125/145) SO_0752 검산항 데이터 수집
# (126/145) SO_0761 녹동항 데이터 수집
# (127/145) DT_0067 안흥 데이터 수집
# (128/145) SO_1255 상태도 데이터 수집
# (129/145) SO_0758 달천도 데이터 수집
# (130/145) SO_0756 사초항 데이터 수집
# (131/145) DT_0063 가덕도 데이터 수집
# (132/145) DT_0062 마산 데이터 수집
# (133/145) SO_1257 강화하리 데이터 수집
# (134/145) DT_0092 여호항 데이터 수집
# (135/145) SO_1258 잠진도 데이터 수집
# ####### SO_1258 잠진도 데이터가 없습니다.
# ####### SO_1258 잠진도 데이터가 없습니다.
# ####### SO_1258 잠진도 데이터가 없습니다.
# ####### SO_1258 잠진도 데이터가 없습니다.
# (136/145) SO_1259 자월도 데이터 수집
# ####### SO_1259 자월도 데이터가 없습니다.
# ####### SO_1259 자월도 데이터가 없습니다.
# ####### SO_1259 자월도 데이터가 없습니다.
# ####### SO_1259 자월도 데이터가 없습니다.
# (137/145) SO_1260 방포항 데이터 수집
# ####### SO_1260 방포항 데이터가 없습니다.
# ####### SO_1260 방포항 데이터가 없습니다.
# ####### SO_1260 방포항 데이터가 없습니다.
# ####### SO_1260 방포항 데이터가 없습니다.
# (138/145) SO_1261 무창포항 데이터 수집
# ####### SO_1261 무창포항 데이터가 없습니다.
# ####### SO_1261 무창포항 데이터가 없습니다.
# ####### SO_1261 무창포항 데이터가 없습니다.
# ####### SO_1261 무창포항 데이터가 없습니다.
# (139/145) SO_1262 격포항 데이터 수집
# ####### SO_1262 격포항 데이터가 없습니다.
# ####### SO_1262 격포항 데이터가 없습니다.
# ####### SO_1262 격포항 데이터가 없습니다.
# ####### SO_1262 격포항 데이터가 없습니다.
# (140/145) SO_1263 구시포항 데이터 수집
# ####### SO_1263 구시포항 데이터가 없습니다.
# ####### SO_1263 구시포항 데이터가 없습니다.
# ####### SO_1263 구시포항 데이터가 없습니다.
# ####### SO_1263 구시포항 데이터가 없습니다.
# (141/145) SO_1264 계마항 데이터 수집
# ####### SO_1264 계마항 데이터가 없습니다.
# ####### SO_1264 계마항 데이터가 없습니다.
# ####### SO_1264 계마항 데이터가 없습니다.
# ####### SO_1264 계마항 데이터가 없습니다.
# (142/145) SO_1265 송이도 데이터 수집
# ####### SO_1265 송이도 데이터가 없습니다.
# ####### SO_1265 송이도 데이터가 없습니다.
# ####### SO_1265 송이도 데이터가 없습니다.
# ####### SO_1265 송이도 데이터가 없습니다.
# (143/145) SO_1266 남열항 데이터 수집
# ####### SO_1266 남열항 데이터가 없습니다.
# ####### SO_1266 남열항 데이터가 없습니다.
# ####### SO_1266 남열항 데이터가 없습니다.
# ####### SO_1266 남열항 데이터가 없습니다.
# (144/145) SO_1267 구룡포항 데이터 수집
# ####### SO_1267 구룡포항 데이터가 없습니다.
# ####### SO_1267 구룡포항 데이터가 없습니다.
# ####### SO_1267 구룡포항 데이터가 없습니다.
# ####### SO_1267 구룡포항 데이터가 없습니다.

# %%
df2
# Out:
#       관측소 번호 관측소 명      위도       경도      Date tph_level             tph_time  \
# 0    SO_0732   남애항  37.944  128.788  20221201        저조  2022-12-01 02:52:00
# 1    SO_0733   강릉항  37.772  128.951  20221201        저조  2022-12-01 03:02:00
# 2    SO_0734   궁촌항  37.327  129.270  20221201        저조  2022-12-01 02:45:00
# 3    SO_0735   죽변항  37.054  129.423  20221201        저조  2022-12-01 03:12:00
# 4    SO_0736   축산항  36.509  129.448  20221201        고조  2022-12-01 08:10:00
# ..       ...   ...     ...      ...       ...       ...                  ...
# 139  SO_1263  구시포항  35.447  126.425  20221201       NaN                  NaN
# 140  SO_1264   계마항  35.390  126.401  20221201       NaN                  NaN
# 141  SO_1265   송이도  35.271  126.150  20221201       NaN                  NaN
# 142  SO_1266   남열항  34.576  127.480  20221201       NaN                  NaN
# 143  SO_1267  구룡포항  35.990  129.555  20221201       NaN                  NaN
#
#     hl_code
# 0        12
# 1        11
# 2        11
# 3        10
# 4        20
# ..      ...
# 139     NaN
# 140     NaN
# 141     NaN
# 142     NaN
# 143     NaN
#
# [432 rows x 8 columns]

# %%
# Out:
# dddd dddd
# 'dddd'
