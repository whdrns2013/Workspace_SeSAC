# %% [markdown]
# # 유형1. 1주차 예상 문제 1
#
# 데이터 출처 : https://data.kma.go.kr/cmmn/static/staticPage.do?page=intro
# 데이터 설명 : 2020년도 이화동(서울) , 수영동(부산)의 시간단위의 기온과 강수량
# 데이터 url : https://raw.githubusercontent.com/Datamanim/datarepo/main/weather/weather2.csv
# 데이터 상위 5개 컬럼
#
# ![image.png](attachment:79e7eb2f-09a1-4f7d-b02e-6977a3a54f3d.png)

# %% [markdown]
# ## import

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/weather/weather2.csv')
df
# Out:
#                      time  이화동강수  이화동기온  수영동강수  수영동기온
# 0     2020-01-01 00:00:00    0.1   -3.9    0.0    2.5
# 1     2020-01-01 01:00:00    0.0   -3.1    0.0    3.4
# 2     2020-01-01 02:00:00    0.0   -1.8    0.0    3.8
# 3     2020-01-01 03:00:00    0.0   -0.8    0.0    4.6
# 4     2020-01-01 04:00:00    0.0   -0.1    0.0    5.1
# ...                   ...    ...    ...    ...    ...
# 8779  2020-12-31 19:00:00    0.0   -9.5    0.0   -4.5
# 8780  2020-12-31 20:00:00    0.0   -9.5    0.0   -5.0
# 8781  2020-12-31 21:00:00    0.0   -9.3    0.0   -6.5
# 8782  2020-12-31 22:00:00    0.0   -9.2    0.0   -4.6
# 8783  2020-12-31 23:00:00    0.0   -7.8    0.0   -0.2
#
# [8784 rows x 5 columns]

# %% [markdown]
# ## Q1. 여름철(6월,7월,8월) 이화동이 수영동보다 높은 기온을 가진 시간대는 몇개인가?

# %%
# 풀이
df2 = df.copy()
df2.loc[pd.to_datetime(df2.time).dt.month.isin([6,7,8])].loc[df2['이화동기온'] > df2['수영동기온']].reset_index(drop=True).count()
# Out:
# time     1415
# 이화동강수    1415
# 이화동기온    1415
# 수영동강수    1415
# 수영동기온    1415
# dtype: int64

# %%
# 해설
# 답안 : 1415개

## 데이터프레임 시간(datetime) 으로 변환
df.time = pd.to_datetime(df.time)

## 시간 정보에서 월 정보 추출
df.time.dt.month

## 특정 월에 속하는 것만 뽑아오기 (두 방법 중 하나)
df[df.time.dt.month.isin([6, 7, 8])]
df.loc[df.time.dt.month.isin([6, 7, 8])]

## index 를 reset하기
### drop = False : 원래 인덱스가 새로운 칼럼으로 들어가고, 리셋된 인덱스가 인덱스가 됨
### drop = True : 인덱스 리셋만 되며, 원래 인덱스는 삭제됨
df.loc[df.time.dt.month.isin([6, 7, 8])].reset_index(drop=True)

## 조건부 (기온 비교)
### df[조건] 과 같은 식도 사용이 가능하지만
### df.loc[조건] 의 방식을 익혀두는 게 좋다.
df[df.time.dt.month.isin([6,7,8])].loc[df['이화동기온'] > df['수영동기온']]
# Out:
#                     time  이화동강수      이화동기온  수영동강수      수영동기온
# 3658 2020-06-01 10:00:00    0.0  19.400000    0.0  19.000000
# 3679 2020-06-02 07:00:00    0.0  21.000000    0.0  19.900000
# 3681 2020-06-02 09:00:00    0.0  20.200001    0.0  19.500000
# 3682 2020-06-02 10:00:00    0.0  19.799999    0.0  19.100000
# 3683 2020-06-02 11:00:00    0.0  19.600000    0.0  19.500000
# ...                  ...    ...        ...    ...        ...
# 5847 2020-08-31 15:00:00    0.0  25.799999    0.0  23.900000
# 5848 2020-08-31 16:00:00    0.0  25.299999    0.0  23.500000
# 5849 2020-08-31 17:00:00    0.0  24.700001    0.0  23.600000
# 5850 2020-08-31 18:00:00    0.0  24.400000    0.0  23.799999
# 5851 2020-08-31 19:00:00    0.0  24.299999    0.0  24.100000
#
# [1415 rows x 5 columns]

# %% [markdown]
# ## Q2. 이화동과 수영동의 최대강수량의 시간대를 각각 구하여라

# %%
# 풀이
import pandas as pd

df3 = df.copy()
df3.time = pd.to_datetime(df3.time)

df3_leehwa = df3.copy().sort_values(by='이화동강수', ascending=False).reset_index(drop=True)
df3_sooyoung = df3.copy().sort_values(by='수영동강수', ascending=False).reset_index(drop=True)

answer = [df3_leehwa.time[0], df3_sooyoung.time[0]]
answer


# 답
# Timestamp('2020-09-30 09:00:00'), Timestamp('2020-07-23 12:00:00')
# Out:
# [Timestamp('2020-09-30 09:00:00'), Timestamp('2020-07-23 12:00:00')]

# %%
# 답안
# 이화동
df.loc[df['이화동강수']==df['이화동강수'].max()].time.values

##2020-09-30T09:00:00

#수영동
df.loc[df['수영동강수']==df['수영동강수'].max()].time.values
##2020-07-23T12:00:00



# 해설
## 특정 셀에서 최댓값 구하기
df['이화동강수'].max()

## 칼럼 중 최댓값과 같은 칼럼 추출
df.loc[df['이화동강수'] == df['이화동강수'].max()]

## 해당 데이터프레임에서 시간값 빼오기
df.loc[df['이화동강수'] == df['이화동강수'].max()].time.values
# Out:
# array(['2020-09-30T09:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# # 유형1. 1주차 예상 문제 2
# 데이터 출처 : https://www.kaggle.com/shubh0799/churn-modelling 에서 변형
# 데이터 설명 :  고객의 신상정보 데이터를 통한 회사 서비스 이탈 예측 (종속변수 : Exited)
# Data url : https://raw.githubusercontent.com/Datamanim/datarepo/main/churn/train.csv

# %% [markdown]
# ## import 및 데이터 탐색

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/churn/train.csv')
df.head(10)
# Out:
#    RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0       6842    15793491  Cherkasova          714   Germany    Male   26
# 1       8963    15607874       Keane          687    France    Male   38
# 2       7047    15737627      Rivero          589   Germany  Female   20
# 3       7503    15697844  Whitehouse          721     Spain  Female   32
# 4       3439    15722404   Carpenter          445    France  Female   30
# 5       7658    15608916    Ndubueze          573    France    Male   40
# 6       5907    15745623     Worsnop          788    France    Male   32
# 7       4272    15707132       Yudin          465    France    Male   33
# 8       9453    15748616  Napolitani          599    France    Male   27
# 9       7048    15731586         Lai          785     Spain  Female   31
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       3  119545.48              2          1               0
# ...

# %% [markdown]
# ## Q1.  남성 이탈(Exited)이 가장 많은 국가(Geography)는 어디이고 이탈 인원은 몇명인가?

# %%
df2 = df.copy().loc[df.Gender == 'Male'].loc[df.Exited ==1].reset_index(drop=True)
df2 = df2.groupby('Geography').count()
df2 = df2.sort_values('Exited', ascending=False)
answer = [df2.index[0], df2.RowNumber[0]]
answer
# Out:
# ['Germany', 287]

# %% [markdown]
# ## Q2. 카드를 소유(HasCrCard ==1)하고 있으면서 활성멤버(IsActiveMember ==1) 인 고객들의 평균나이는?

# %%
df3 = df.copy().loc[df.HasCrCard == 1].loc[df.IsActiveMember == 1]
answer = df3.Age.mean()
answer
# Out:
# 39.61019283746556

# %% [markdown]
# ## Balance 값이 중간값 이상을 가지는 고객들의 CreditScore의 표준편차를 구하여라

# %%
df4 = df.copy()
df4.describe()

df4 = df4.copy().loc[df4.Balance >= 97259.250000]
answer = df4.CreditScore.std()
answer
# Out:
# 97.29451567120793

# %% [markdown]
# # 유형1. 1주차 예상 문제 3
# 데이터 출처 :https://www.data.go.kr/data/15007122/fileData.do (참고, 데이터 수정)
# 데이터 설명 : 2018년도 성인의 건강검 진데이터 (흡연상태 1- 흡연, 0-비흡연 )
# 데이터 url : https://raw.githubusercontent.com/Datamanim/datarepo/main/smoke/train.csv
# 데이터 상위 5개 컬럼
#
# ![image.png](attachment:378f9fe1-3b88-44ce-8202-8beaf5b4db1a.png)

# %% [markdown]
# ## import 및 탐색

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/smoke/train.csv')
df
# Out:
#       성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 0        F           55        145         55  73.0    0.7    0.5    1.0
# 1        M           40        180         55  74.0    1.5    1.5    1.0
# 2        F           55        150         50  72.0    1.0    0.2    1.0
# 3        M           40        170         85  89.0    1.0    0.8    1.0
# 4        F           40        155         45  62.0    0.5    1.0    1.0
# ...    ...          ...        ...        ...   ...    ...    ...    ...
# 44548    F           60        145         50  87.0    1.0    1.0    1.0
# 44549    M           40        175         75  88.0    1.5    1.2    1.0
# 44550    F           60        150         55  82.0    0.9    0.9    1.0
# 44551    M           40        170         50  69.0    0.4    1.2    1.0
# 44552    F           40        155         50  72.5    1.0    1.0    1.0
#
#        청력(우)  수축기혈압  ...   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  \
# ...

# %% [markdown]
# ## Q1. 시력(좌) 와 시력(우)의 값이 같은 남성의 허리둘레의 평균은?

# %%
answer = df.copy().loc[df['시력(좌)'] == df['시력(우)']].loc[df['성별코드']=='M']['허리둘레'].mean()
answer
# Out:
# 84.9768266281797

# %% [markdown]
# ## Q2. 40대(연령대코드 40,45) 여성 중 '총콜레스테롤'값이 40대 여성의 '총콜레스테롤'
#
# 40대(연령대코드 40,45) 여성 중 '총콜레스테롤'값이 40대 여성의 '총콜레스테롤' 중간값 이상을  가지는 그룹과
# 50대(연령대코드 50,55) 여성 중 '총콜레스테롤'값이 50대 여성의 '총콜레스테롤' 중간값 이상을 가지는 두 그룹의
# '수축기혈압'이 독립성,정규성,등분산성이 만족하는것을 확인했다.
#
# 두 그룹의 '수축기혈압'의 독립표본 t 검증 결과를 통계값, p-value 구분지어 구하여라.

# %%
df40 = df.copy().loc[df['연령대코드(5세단위)'].isin([40, 45])].loc[df['성별코드']=='F'].loc[df['총콜레스테롤'] > df['총콜레스테롤'].median()]
df50 = df.copy().loc[df['연령대코드(5세단위)'].isin([50, 55])].loc[df['성별코드']=='F'].loc[df['총콜레스테롤'] > df['총콜레스테롤'].median()]

import scipy.stats
scipy.stats.ttest_ind(df40, df50, equal_var=True)

# %% [markdown]
# # 4

# %% [markdown]
# # 5

# %% [markdown]
# # 6

# %% [markdown]
# # 7

# %% [markdown]
# # 8

# %% [markdown]
# # 9

# %% [markdown]
# # 10

# %% [markdown]
# # 11

# %% [markdown]
# # 12
