# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 기본 탐색

# %%
df = pd.read_csv('houseprice.csv')

# %%
df.head(), df.describe(), df.info()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # 전처리

# %%
## 결측치 확인
isnull_series = df.isnull().sum()
isnull_series[isnull_series>0].sort_values(ascending = False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
## 분산 확인
plt.xticks(rotation=45)
sns.histplot(df['SalePrice'], kde=True)
plt.show()

# %%
## 스케일링, 정규화
### -> 타겟값이 정규분포가 아니라면, 정규분포화 해준 후 분석하는 것이 효과적이다.
log_saleprice = np.log1p(df['SalePrice'])
sns.histplot(log_saleprice, kde=True)
plt.show()

### 로그취한 값을 덮어쓰기
original_saleprice = df['SalePrice']
df['SalePrice'] = np.log1p(df['SalePrice'])

### 필요없는 칼럼 제거, na값 많은 칼럼 제거
df.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'Id'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8828\2120803900.py in <module>
#      10
#      11 ### 필요없는 칼럼 제거, na값 많은 칼럼 제거
# ---> 12 df.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'Id'], inplace=True)
#      13
#      14 ### 그 외 na값은 평균값으로 대체
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'Id'] not found in axis"

# %%
## 그 외 na값 처리
### 수치값 칼럼은 평균값으로 대체
df.fillna(df.mean(), inplace=True)

### Object타입인 칼럼들만이 남았다.
### 확인해보자
null_column_count = df.isnull().sum()[df.isnull().sum()>0]
df.dtypes[null_column_count.index]
# Out:
# MasVnrType      object
# BsmtQual        object
# BsmtCond        object
# BsmtExposure    object
# BsmtFinType1    object
# BsmtFinType2    object
# Electrical      object
# GarageType      object
# GarageFinish    object
# GarageQual      object
# GarageCond      object
# dtype: object

# %%
## Object 타입은 인코딩으로 범주화 처리를 한다.
df_ohe = pd.get_dummies(df)
df_ohe.shape
# Out:
# (1460, 271)

# %% [markdown]
# # 평가모델 생성

# %%
# RMSE 평가 모델 생성
def get_rmse(model):
    from sklearn.metrics import mean_squared_error
    import numpy as np
    pred = model.predict(X_test)
    mse = mean_squared_error(y_test, pred)
    rmse = np.sqrt(mse)
    print(model.__class__.__name__, '로그 변환된 RMSE : ', np.round(rmse,3))
    return rmse

# 여러 모델을 RMSE 평가하는 함수
def get_rmses(models):
    rmses = []
    for model in models:
        rmses.append(get_rmse(model))
    return rmses

# %% [markdown]
# # 회귀 개선

# %%
## L1, L2 규제를 이용한다.
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split

# %%
## 데이터셋 나누기
y = df_ohe['SalePrice']
X = df_ohe.drop(columns = 'SalePrice')

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=156)

# %%
## 회귀 모델 지정
## 및 학습 진행
lr_reg = LinearRegression()
lr_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
## 릿지 모델 지정
## 및 학습 진행
ridge_reg = Ridge()
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge()

# %%
## 라쏘 모델 지정
## 및 학습 진행
lasso_reg = Lasso()
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso()

# %%
## RMSE값 받아보기
models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models)
# Out:
# LinearRegression 로그 변환된 RMSE :  0.001
# Ridge 로그 변환된 RMSE :  0.001
# Lasso 로그 변환된 RMSE :  0.003
# [0.0013147749234460775, 0.001244312208664437, 0.003450378535774347]

# %%
## 로그 역변환 - 못봄
np.expm1(

# %%
## coef 평가????
def get_top_bottom_coef(model, n=10):
    coef = pd.Series(model.coef_,index=X.columns)
    coef_high = coef.sort_values(ascending=False).head(n)
    coef_low = coef.sort_values(ascending=True).head(n)
    return coef_high, coef_low

# %%
## coef 적용
get_top_bottom_coef(ridge_reg)
# Out:
# (RoofMatl_WdShngl        0.002009
#  RoofMatl_CompShg        0.001426
#  Neighborhood_StoneBr    0.001394
#  Condition2_Norm         0.001177
#  Neighborhood_Crawfor    0.001177
#  Neighborhood_NridgHt    0.001128
#  Heating_GasW            0.001053
#  RoofMatl_WdShake        0.001030
#  MSZoning_FV             0.000950
#  Functional_Typ          0.000929
#  dtype: float64,
#  RoofMatl_ClyTile       -0.006493
#  Condition2_PosN        -0.003141
#  MSZoning_C (all)       -0.002922
#  Functional_Maj2        -0.002620
#  Heating_Grav           -0.002021
#  Neighborhood_MeadowV   -0.001953
#  Utilities_NoSeWa       -0.000802
#  GarageType_2Types      -0.000724
#  Neighborhood_Edwards   -0.000707
#  Neighborhood_BrDale    -0.000650
#  dtype: float64)

# %%
def visualize_coefficient(models):
    fig, axs = plt.subplots(figsize=(24,10), nrows=1, ncols=3)
    fig.tight_layout()      # 동일 면에 표시되는 각기 다른 그래프의 표시범주가 비슷해보이게 함
    for i_num, model in enumerate(models):
        coef_high, coef_low = get_top_bottom_coef(model)
        coef_concat = pd.concat([coef_high, coef_low])
        axs[i_num].set_title(model.__class__.__name__+ ' Coefficient', size=25)
        axs[i_num].tick_params(axis='y', direction='in', pad=120)
        for label in (axs[i_num].get_xticklabels()+axs[i_num].get_yticklabels()):
            label.set_fontsize(22)
        sns.barplot(x=coef_concat.values, y=coef_concat.index, ax=axs[i_num])

# %%
visualize_coefficient(models)

# %%
corr_col_list = []
corr_val_list = []


for (i, j) in enumerate(df):
    if df[j].dtype == 'object':
        continue
    else:
        print(f'SalePrice와 {j}의 상관도 : ')
        print(df['SalePrice'].corr(df[j]))
        corr_col_list.append(j) 
        corr_val_list.append(abs(df['SalePrice'].corr(df[j])))
        
df_corr = pd.DataFrame([corr_col_list, corr_val_list]).transpose()
df_corr.columns = ['corr_col_list', 'corr_val_list']
df_corr.corr_val_list = df_corr.corr_val_list.astype(float)
df_corr.sort_values(by='corr_val_list', ascending=False, inplace=True)
# Out:
# SalePrice와 MSSubClass의 상관도 :
# -0.07182289518661983
# SalePrice와 LotFrontage의 상관도 :
# 0.33399161807513517
# SalePrice와 LotArea의 상관도 :
# 0.2545369150851456
# SalePrice와 OverallQual의 상관도 :
# 0.813938121247517
# SalePrice와 OverallCond의 상관도 :
# -0.030261122444329144
# SalePrice와 YearBuilt의 상관도 :
# 0.5883289751069889
# SalePrice와 YearRemodAdd의 상관도 :
# 0.5671387240291567
# SalePrice와 MasVnrArea의 상관도 :
# 0.421937975918094
# SalePrice와 BsmtFinSF1의 상관도 :
# 0.3685475814961511
# SalePrice와 BsmtFinSF2의 상관도 :
# 0.006823875030610731
# SalePrice와 BsmtUnfSF의 상관도 :
# 0.22054106211118377
# SalePrice와 TotalBsmtSF의 상관도 :
# 0.6077985919652509
# SalePrice와 1stFlrSF의 상관도 :
# 0.5920215977565589
# SalePrice와 2ndFlrSF의 상관도 :
# 0.3169525953049179
# SalePrice와 LowQualFinSF의 상관도 :
# -0.03864505226268216
# SalePrice와 GrLivArea의 상관도 :
# 0.6952649062244961
# SalePrice와 BsmtFullBath의 상관도 :
# 0.23542143630446044
# SalePrice와 BsmtHalfBath의 상관도 :
# -0.0029886598805220145
# SalePrice와 FullBath의 상관도 :
# 0.5934523206098622
# SalePrice와 HalfBath의 상관도 :
# 0.3148171308591804
# SalePrice와 BedroomAbvGr의 상관도 :
# 0.2128281358542079
# SalePrice와 KitchenAbvGr의 상관도 :
# -0.14703616253039237
# SalePrice와 TotRmsAbvGrd의 상관도 :
# 0.5309339070995186
# SalePrice와 Fireplaces의 상관도 :
# 0.48794593810736464
# SalePrice와 GarageYrBlt의 상관도 :
# 0.4987931046533921
# SalePrice와 GarageCars의 상관도 :
# 0.6798020654413454
# SalePrice와 GarageArea의 상관도 :
# 0.6489289229954456
# SalePrice와 WoodDeckSF의 상관도 :
# 0.33260127223824576
# SalePrice와 OpenPorchSF의 상관도 :
# 0.317731477477526
# SalePrice와 EnclosedPorch의 상관도 :
# -0.15014720859612055
# SalePrice와 3SsnPorch의 상관도 :
# 0.05547929116759161
# SalePrice와 ScreenPorch의 상관도 :
# 0.12152555670054514
# SalePrice와 PoolArea의 상관도 :
# 0.06789868750196684
# SalePrice와 MiscVal의 상관도 :
# -0.01990758179451715
# SalePrice와 MoSold의 상관도 :
# 0.05742254231191561
# SalePrice와 YrSold의 상관도 :
# -0.03815111017909454
# SalePrice와 SalePrice의 상관도 :
# 0.9999999999999999
#     corr_col_list  corr_val_list
# 36      SalePrice       1.000000
# 3     OverallQual       0.813938
# 15      GrLivArea       0.695265
# 25     GarageCars       0.679802
# 26     GarageArea       0.648929
# 11    TotalBsmtSF       0.607799
# 18       FullBath       0.593452
# 12       1stFlrSF       0.592022
# 5       YearBuilt       0.588329
# 6    YearRemodAdd       0.567139
# 22   TotRmsAbvGrd       0.530934
# 24    GarageYrBlt       0.498793
# 23     Fireplaces       0.487946
# 7      MasVnrArea       0.421938
# 8      BsmtFinSF1       0.368548
# 1     LotFrontage       0.333992
# 27     WoodDeckSF       0.332601
# 28    OpenPorchSF       0.317731
# 13       2ndFlrSF       0.316953
# 19       HalfBath       0.314817
# 2         LotArea       0.254537
# 16   BsmtFullBath       0.235421
# 10      BsmtUnfSF       0.220541
# 20   BedroomAbvGr       0.212828
# 29  EnclosedPorch       0.150147
# 21   KitchenAbvGr       0.147036
# 31    ScreenPorch       0.121526
# 0      MSSubClass       0.071823
# 32       PoolArea       0.067899
# 34         MoSold       0.057423
# 30      3SsnPorch       0.055479
# 14   LowQualFinSF       0.038645
# 35         YrSold       0.038151
# 4     OverallCond       0.030261
# 33        MiscVal       0.019908
# 9      BsmtFinSF2       0.006824
# 17   BsmtHalfBath       0.002989
