# %% [markdown]
# # folium
#
# * 설치 : https://python-visualization.github.io/folium/installing.html
# * Map을 사용할 수 있게 해주는 라이브러리이다.
#
# > 맵 만들기
# > * `folium.Map([위도,경도], 기타 옵션)` : 지도 만들기 . 위도 경도는 리스트[] 혹은 튜플() 형태로 지정이 가능
# > * `MAP.save('파일명')` : 파일명으로 지도 저장
# >
# > 맵 만들기 - 옵션
# > * `zoom_start=확대정도int` : 확대 정도
# > * `tiles = 'Stamen Toner'` : 흑백 지도
# > * `tiles = 'Stamen Watercolor'` : 수채화 지도
#
#
# > 마커
# > * `folium.Marker([마커위도,경도], 옵션들).add_to(마킹할 지도)` : 마커 만들기
# >
# > 마커 옵션
# > * `popup = '마커 이름'` : 마커 이름 지정
# > * `tooltip = '마우스 댔을 때 말풍선'` : 마우스 댔을 때 말풍선 이름
# > * `color = '컬러'` : 마커 컬러 지정. red, blue ... 등 몇 가지 지원함
# > * `icon=folium.Icon(icon="아이콘")` : 마커 아이콘 지정. cloud, start 등 지원
# > * `radius = int` : 마커 중심으로 동그란 원 생성
# > * `fill_color='컬러'` : 채우기 색
# > * `opacity = int` : 채우기 투명도 지정

# %% [markdown]
# ## 맵 만들기

# %%
import folium

# %%
# 맵 만들기 및 저장

m = folium.Map([37.5176577,126.8864088], zoom_start=16)
m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c96ba831ba4e6361c6ae9efceb96a287 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c96ba831ba4e6361c6ae9efceb96a287&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c96ba831ba4e6361c6ae9efceb96a287 = L.map(
#                 &quot;map_c96ba831ba4e6361c6ae9efceb96a287&quot;,
#                 {
#                     center: [37.5176577, 126.8864088],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ffdc0f27c73042e7b93720d5deaee4f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c96ba831ba4e6361c6ae9efceb96a287);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 맵 만들기 옵션
m = folium.Map([37.5176577,126.8864088], zoom_start=16, tiles='Stamen Toner')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7beefbbae383cd514a3b2537430ffc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7beefbbae383cd514a3b2537430ffc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7beefbbae383cd514a3b2537430ffc8 = L.map(
#                 &quot;map_a7beefbbae383cd514a3b2537430ffc8&quot;,
#                 {
#                     center: [37.5176577, 126.8864088],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53def77abcf8771d83f6c57e9a8f65a2 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a7beefbbae383cd514a3b2537430ffc8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 마커
m = folium.Map([37.5176577,126.8864088], zoom_start=16)
folium.Marker((37.5176577,126.8864088), popup='새싹', tooltip='여기는 어디?!').add_to(m)
folium.Marker((37.5176654,126.8834888), icon=folium.Icon(icon="cloud")).add_to(m)
folium.Marker((37.5196654,126.8884888), radius = 20, fill_color='red', opacity=0.5).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7cfbc0bdab8b0409ff859293b6df513 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7cfbc0bdab8b0409ff859293b6df513&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7cfbc0bdab8b0409ff859293b6df513 = L.map(
#                 &quot;map_c7cfbc0bdab8b0409ff859293b6df513&quot;,
#                 {
#                     center: [37.5176577, 126.8864088],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae46661c5822cd0adca0f2de06ad0047 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
#
#             var marker_0a5a162f6ebffc04840bbf73c378802b = L.marker(
#                 [37.5176577, 126.8864088],
#                 {}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
#
#         var popup_0e40f2163192fc565b35029b44d16bcb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2effe2fddfe4c451041521a6e7f6cecf = $(`&lt;div id=&quot;html_2effe2fddfe4c451041521a6e7f6cecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;새싹&lt;/div&gt;`)[0];
#                 popup_0e40f2163192fc565b35029b44d16bcb.setContent(html_2effe2fddfe4c451041521a6e7f6cecf);
#
#
#
#         marker_0a5a162f6ebffc04840bbf73c378802b.bindPopup(popup_0e40f2163192fc565b35029b44d16bcb)
#         ;
#
#
#
#
#             marker_0a5a162f6ebffc04840bbf73c378802b.bindTooltip(
#                 `&lt;div&gt;
#                      여기는 어디?!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2b9dc53d99e9df8172a8145f7b41253e = L.marker(
#                 [37.5176654, 126.8834888],
#                 {}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
#
#             var icon_78967a8df4e6a1aef87bfe5cfb0c0797 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2b9dc53d99e9df8172a8145f7b41253e.setIcon(icon_78967a8df4e6a1aef87bfe5cfb0c0797);
#
#
#             var marker_ec6e0e1e36ab524de7398d4c1be98121 = L.marker(
#                 [37.5196654, 126.8884888],
#                 {&quot;fillColor&quot;: &quot;red&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 20}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 실습 아래 로또 상점 리스트 마커 추가

# 로또 상점 리스트
lotto = [
{"store":"담배","loc":[37.62585944357624,127.01847823823798]},
{"store":"화곡본마트","loc":[37.54248103738589,126.84414659211494]},
{"store":"용꿈돼지꿈","loc":[37.5447438346992,126.95223862043447]},
{"store":"일이오마켓","loc":[37.47943673430032,126.98346178441342]},
{"store":"여명슈퍼마켓","loc":[37.61432815661055,127.0415039221072]},
{"store":"5가로또레드탑","loc":[37.570756251987575,127.00235901546226]},
{"store":"복권세상","loc":[35.91885025656432,128.55034430109828]},
{"store":"복권전문점","loc":[37.50384327747725,126.71513104367074]},
{"store":"인현동지하가판","loc":[37.47627910055104,126.63147671205866]},
{"store":"CU(광주서동점)","loc":[35.14814807640179,126.90555219336346]},
{"store":"지산로또방","loc":[35.148338888178,126.93203920504686]},
{"store":"천사로또방","loc":[37.63618838692431,127.21107884503209]},
{"store":"오렌지통신","loc":[37.42889361993242,127.10232604117991]},
{"store":"여수복권방","loc":[37.418353650942116,127.12640523182601]},
{"store":"둘리복권방","loc":[37.34532813934063,126.73627994929885]},
{"store":"금성24시편의점","loc":[37.84401249737699,127.06236893072152]},
{"store":"GS25(청주주은점)","loc":[36.60987111587086,127.49134026856717]},
{"store":"장미슈퍼","loc":[36.276304155315685,126.90940713047799]},
{"store":"장미슈퍼","loc":[36.276304155315685,126.90940713047799]},
{"store":"아이24(수송점)","loc":[35.970108052787594,126.7189421934312]},
{"store":"탑로또","loc":[34.87844231008963,128.62803523643754]}
]


# 마커 추가
for i in lotto:
    folium.Marker(i.get("loc"), popup=i.get("store"), tooltip=i.get("store")).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7cfbc0bdab8b0409ff859293b6df513 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7cfbc0bdab8b0409ff859293b6df513&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7cfbc0bdab8b0409ff859293b6df513 = L.map(
#                 &quot;map_c7cfbc0bdab8b0409ff859293b6df513&quot;,
#                 {
#                     center: [37.5176577, 126.8864088],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae46661c5822cd0adca0f2de06ad0047 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
#
#             var marker_0a5a162f6ebffc04840bbf73c378802b = L.marker(
#                 [37.5176577, 126.8864088],
#                 {}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
#
#         var popup_0e40f2163192fc565b35029b44d16bcb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2effe2fddfe4c451041521a6e7f6cecf = $(`&lt;div id=&quot;html_2effe2fddfe4c451041521a6e7f6cecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;새싹&lt;/div&gt;`)[0];
#                 popup_0e40f2163192fc565b35029b44d16bcb.setContent(html_2effe2fddfe4c451041521a6e7f6cecf);
#
#
#
#         marker_0a5a162f6ebffc04840bbf73c378802b.bindPopup(popup_0e40f2163192fc565b35029b44d16bcb)
#         ;
#
#
#
#
#             marker_0a5a162f6ebffc04840bbf73c378802b.bindTooltip(
#                 `&lt;div&gt;
#                      여기는 어디?!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2b9dc53d99e9df8172a8145f7b41253e = L.marker(
#                 [37.5176654, 126.8834888],
#                 {}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
#
#             var icon_78967a8df4e6a1aef87bfe5cfb0c0797 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2b9dc53d99e9df8172a8145f7b41253e.setIcon(icon_78967a8df4e6a1aef87bfe5cfb0c0797);
#
#
#             var marker_ec6e0e1e36ab524de7398d4c1be98121 = L.marker(
#                 [37.5196654, 126.8884888],
#                 {&quot;fillColor&quot;: &quot;red&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 20}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
#
#             var marker_96ec7d706418a3f92a5d053655b4ddff = L.marker(
#                 [37.62585944357624, 127.01847823823798],
#                 {}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
#
#         var popup_dcf15cdf1cdf2b736cb0774be45028be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa71cd27dbba22a29563f56815f0e5ad = $(`&lt;div id=&quot;html_aa71cd27dbba22a29563f56815f0e5ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;담배&lt;/div&gt;`)[0];
#                 popup_dcf15cdf1cdf2b736cb0774be45028be.setContent(html_aa71cd27dbba22a29563f56815f0e5ad);
#
#
#
#         marker_96ec7d706418a3f92a5d053655b4ddff.bindPopup(popup_dcf15cdf1cdf2b736cb0774be45028be)
#         ;
#
#
#
#
#             var marker_455333259dfd9ea58c986e0f4d56affa = L.marker(
#                 [37.54248103738589, 126.84414659211494],
#                 {}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
#
#         var popup_2b1ff7fd9c9c1f7e77b8419e3241634d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59d7410fdaac72a048a4fe42520ed3a1 = $(`&lt;div id=&quot;html_59d7410fdaac72a048a4fe42520ed3a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;화곡본마트&lt;/div&gt;`)[0];
#                 popup_2b1ff7fd9c9c1f7e77b8419e3241634d.setContent(html_59d7410fdaac72a048a4fe42520ed3a1);
#
#
#
#         marker_455333259dfd9ea58c986e0f4d56affa.bindPopup(popup_2b1ff7fd9c9c1f7e77b8419e3241634d)
#         ;
#
#
#
#
#             var marker_d15f48876705591f5ea3e3222e72b6c4 = L.marker(
#                 [37.5447438346992, 126.95223862043447],
#                 {}
#             ).addTo(map_c7cfbc0bdab8b0409ff859293b6df513);
#
#
#         var popup_eab170fbe03cc4eaf79926c4b0798c32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d4cbe9c47a9d07b0f747e32e4a90933 = $(`&lt;div id=&quot;html_4d4cbe9c47a9d07b0f747e32e4a90933&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;용꿈돼지꿈&lt;/div&gt;`)[0];
#                 popup_eab170fbe03cc4eaf79926c4b0798c32.setContent(html_4d4cbe9c47a9d07b0f747e32e4a90933);

# %% [markdown]
# ## 마커 클러스터 : 마커끼리 묶어 군집 형성
#
# * 가까운 곳의 마커끼리 zoom 단계에 따라 묶는 것
# ![image.png](attachment:e4126662-42bd-4326-891d-f4e965cef64d.png)

# %%
from folium.plugins import MarkerCluster

m = folium.Map([37.5176577,126.8864088], zoom_start=16)
mc = MarkerCluster().add_to(m)
for i in lotto:
    folium.Marker(i.get("loc"), popup=i.get("store"), tooltip=i.get("store")).add_to(mc)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b809c605c6a6c12e1e44428325aeeb1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b809c605c6a6c12e1e44428325aeeb1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b809c605c6a6c12e1e44428325aeeb1c = L.map(
#                 &quot;map_b809c605c6a6c12e1e44428325aeeb1c&quot;,
#                 {
#                     center: [37.5176577, 126.8864088],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f97c1923911afe30c3bbc8eac2039f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b809c605c6a6c12e1e44428325aeeb1c);
#
#
#             var marker_cluster_30b6fd7729046593b623af18ff60729d = L.markerClusterGroup(
#                 {}
#             );
#             map_b809c605c6a6c12e1e44428325aeeb1c.addLayer(marker_cluster_30b6fd7729046593b623af18ff60729d);
#
#
#             var marker_9d39273b9f212cfce59ccf4f656ead70 = L.marker(
#                 [37.62585944357624, 127.01847823823798],
#                 {}
#             ).addTo(marker_cluster_30b6fd7729046593b623af18ff60729d);
#
#
#         var popup_9517ee9be158ff3b78459124244b8c1b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0efc75055c59b91fcfa84ce5affefd26 = $(`&lt;div id=&quot;html_0efc75055c59b91fcfa84ce5affefd26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;담배&lt;/div&gt;`)[0];
#                 popup_9517ee9be158ff3b78459124244b8c1b.setContent(html_0efc75055c59b91fcfa84ce5affefd26);
#
#
#
#         marker_9d39273b9f212cfce59ccf4f656ead70.bindPopup(popup_9517ee9be158ff3b78459124244b8c1b)
#         ;
#
#
#
#
#             marker_9d39273b9f212cfce59ccf4f656ead70.bindTooltip(
#                 `&lt;div&gt;
#                      담배
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aac81605284ae87f3bfbff244d7da01a = L.marker(
#                 [37.54248103738589, 126.84414659211494],
#                 {}
#             ).addTo(marker_cluster_30b6fd7729046593b623af18ff60729d);
#
#
#         var popup_cbec5dce43fddb5db899e035213b7269 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0dae847aaeb0e46a7dbab1e8450579a1 = $(`&lt;div id=&quot;html_0dae847aaeb0e46a7dbab1e8450579a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;화곡본마트&lt;/div&gt;`)[0];
#                 popup_cbec5dce43fddb5db899e035213b7269.setContent(html_0dae847aaeb0e46a7dbab1e8450579a1);
#
#
#
#         marker_aac81605284ae87f3bfbff244d7da01a.bindPopup(popup_cbec5dce43fddb5db899e035213b7269)
#         ;
#
#
#
#
#             marker_aac81605284ae87f3bfbff244d7da01a.bindTooltip(
#                 `&lt;div&gt;
#                      화곡본마트
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_591ac31ecc56c879c1e1abca8b7cee64 = L.marker(
#                 [37.5447438346992, 126.95223862043447],
#                 {}
#             ).addTo(marker_cluster_30b6fd7729046593b623af18ff60729d);
#
#
#         var popup_18086c23f2de7b007251a88fce77c9cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c675004af4fefa4e08f43b7253b0de78 = $(`&lt;div id=&quot;html_c675004af4fefa4e08f43b7253b0de78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;용꿈돼지꿈&lt;/div&gt;`)[0];
#                 popup_18086c23f2de7b007251a88fce77c9cf.setContent(html_c675004af4fefa4e08f43b7253b0de78);
#
#
#
#         marker_591ac31ecc56c879c1e1abca8b7cee64.bindPopup(popup_18086c23f2de7b007251a88fce77c9cf)
#         ;
#
#
#
#
#             marker_591ac31ecc56c879c1e1abca8b7cee64.bindTooltip(
#                 `&lt;div&gt;
#                      용꿈돼지꿈
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_17e85ef35175142143a03453bfbec203 = L.marker(
#                 [37.47943673430032, 126.98346178441342],
#                 {}
#             ).addTo(marker_cluster_30b6fd7729046593b623af18ff60729d);
#
#
#         var popup_9d98b88f8c844965e8f9ac2d17e57465 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22e8e6d4b55be08260acdc73654ba9e

# %% [markdown]
# ## GeoJSON
#
# * 지도 위에 면적 표기 등의 기능을 제공함

# %%
import json

m = folium.Map((37.54277566660933,130.91636374950804))

## geo json 파일 불러오기 - 두 단계로 하면 오류 발생 안함
json_data = open('map.geojson','r').read()
json_data = json.loads(json_data)

## 맵에 geoJson 추가
folium.GeoJson(json_data).add_to(m)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25116\3032937007.py in <module>
#       5 ## geo json 파일 불러오기 - 두 단계로 하면 오류 발생 안함
#       6 json_data = open('map.geojson','r').read()
# ----> 7 json_data = json.loads(json_data)
#       8
#       9 ## 맵에 geoJson 추가
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 94 column 7 (char 2121)

# %% [markdown]
# # 카카오 지도 API 이용 방법
#
# * https://developers.kakao.com/
#
# ![image.png](attachment:5c978597-79ec-4bb3-a3d8-e6c4474da941.png)

# %% [markdown]
# # 실습 : 제주 인구
#
# * 마커로 제주의 동을 모두 표시
# * 인구별로 마커의 색상을 다르게 함
#
# > 위경도 : 카카오 API 이용
# >

# %%
# 내 카카오 Dev API 키
REST_API_KEY = '87376327ebc82d4265d05d66c9123651'

# %%
# csv 파일 불러오기
import pandas as pd
jeju = pd.read_csv('jeju.csv', encoding='cp949')
jeju.sample(5)
# Out:
#       지역   읍면동          전화번호                          주소  \
# 3    제주시  이도2동  064-755-2021   제주특별자치도 제주시 오복3길 8 (이도이동)
# 38  서귀포시   서홍동  064-760-4745   제주특별자치도 서귀포시 중앙로 125(서홍동)
# 33  서귀포시   중앙동  064-760-4562  제주특별자치도 서귀포시 동문동로 27 (서귀동)
# 40  서귀포시   대천동  064-760-4785   제주특별자치도 서귀포시 도순로 44 (도순동)
# 4    제주시  삼도1동  064-728-4532   제주특별자치도 제주시 전농로 40 (삼도일동)
#
#                                               일반현황  \
# 3                   인구 41428명 / 면적 5.4㎢ / 49통 323반
# 38  인구 10697명('18.12.31. 현재) / 면적 13.34k㎡ / 5통 30반
# 33       인구 4003명('17. 12. 31. 현재) 면적 0.45㎢ 8통 41반
# 40      인구 11310명 / 면적 50.5㎢ / 7통 51반 ('17.4.30기준)
# 4                    인구 14281명 / 면적0.87㎢ / 18통122반
#
#                           청사현황                        자치센터현황     데이터기준일자  \
# 3   지하 1층·지상 3층 / 연면적 1223.52㎡  총면적 388.9㎡  / 개소일 2000-10-05  2019-06-20
# 38           지상 3층 / 연면적 1134㎡  총면적 631.47㎡ / 개소일 2000-12-27  2019-06-20
# 33   지상 3층 지하 1층 (연면적 769.87㎡)                           NaN  2019-06-20
# 40         지상 2층 / 연면적 300.48㎡     총면적 90평 /  개소일 2000-12-28  2019-06-20
# 4    지하 1층·지상3층 / 연면적 2070.37㎡                   총면적 456.55㎡  2019-06-20
#
#     Unnamed: 8
# 3          NaN
# 38         NaN
# 33         NaN
# 40         NaN
# 4          NaN

# %%
# 데이터 크롤링 라이브러리 : request

# %% [markdown]
# ### 요청 방법
# GET /v2/local/search/address.${FORMAT} HTTP/1.1
# Host: dapi.kakao.com
# Authorization: KakaoAK ${REST_API_KEY}
#
# ### sample
# curl -v -X GET "https://dapi.kakao.com/v2/local/search/address.json" \
#   -H "Authorization: KakaoAK ${REST_API_KEY}" \
#   --data-urlencode "query=전북 삼성동 100"
