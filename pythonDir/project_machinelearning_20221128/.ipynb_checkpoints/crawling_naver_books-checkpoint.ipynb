# %% [markdown]
# # API 크롤링

# %% [markdown]
# # API 크롤링 정보
#
# * url : https://search.shopping.naver.com/book/catalog/책번호

# %%
# API 통신을 할 때 사용하는 라이브러리
import requests
# 가져온 페이지의 html을 파싱하는 라이브러리
from bs4 import BeautifulSoup
# 그 외 툴들 import
import pandas as pd
import numpy as np

# %%
url_base = "https://search.shopping.naver.com/book/catalog/"
bookno_list = []
# 지정한 url로 페이지를 가져오는 요청을 생성함
# bookno_list : 크롤링할 책의 No

res = requests.get(url)
# url의 requests를 가져요는 것을 res 변수에 담아줌

res.raise_for_status()
soup = BeautifulSoup(res.text, "lxml")
# 요청을 통해 가져온 페이지를 BeautifulSoup로 파싱함
# lxml : html 및 xml의 파싱을 간편하게 도와주는 라이브러리

# %%
# 크롤링 함수 정의

def crawling_naver_books(bookno):
    
    import requests
    from bs4 import BeautifulSoup
    
    url_base = "https://search.shopping.naver.com/book/catalog/"
    url = url_base + str(bookno)
    
    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'lxml')
    
    return soup

# %%
def pick_books_info(bookno):
    
    import pandas as pd
    import numpy as np
    
    data = crawling_naver_books(bookno)
    
    book_test = str(data.find_all('div', attrs={'class' : 'bookTitle_info_content__iHfCC'})[1]).replace('<div class="bookTitle_info_content__iHfCC"><span class="bookTitle_inner_content__REoK1">','').replace('</span></div>','')
    book_find_all = str(data.find_all('div', attrs={'class' : 'bookBasicInfo_info_detail__I0Fx5'})[0])
    
    book_title = str(data.find('h2', attrs={'class' : 'bookTitle_book_name__JuBQ2'})).replace('<h2 class="bookTitle_book_name__JuBQ2">','').replace('</h2>','') # 책 제목
    book_subtitiel = str(data.find('span', attrs={'class' : 'bookTitle_sub_title__B0uMS'})).replace('<span class="bookTitle_sub_title__B0uMS">','').replace('</span>','') # 책 subtitle
    book_author = str(data.find_all('div', attrs={'class' : 'bookTitle_info_content__iHfCC'})[0]).replace('<div class="bookTitle_info_content__iHfCC"><span class="bookTitle_inner_content__REoK1">','').replace('</span></div>','') # 저자
    book_publisher = str(data.find_all('div', attrs={'class' : 'bookTitle_info_content__iHfCC'})[1]).replace('<div class="bookTitle_info_content__iHfCC"><span class="bookTitle_inner_content__REoK1">','').replace('</span></div>','') # 출판사
    book_category = str(data.find_all('div', attrs={'class' : 'bookBasicInfo_info_detail__I0Fx5'})[0]).replace('<div class="bookBasicInfo_info_detail__I0Fx5">','').replace('</div>','')
    book_pages = str(data.find_all('div', attrs={'class' : 'bookBasicInfo_info_detail__I0Fx5'})[1]).replace('<div class="bookBasicInfo_info_detail__I0Fx5">','').replace('</div>','')
    book_weight = str(data.find_all('div', attrs={'class' : 'bookBasicInfo_info_detail__I0Fx5'})[2]).replace('<div class="bookBasicInfo_info_detail__I0Fx5">','').replace('</div>','')
#     book_big = 
#     book_introduce = 
#     book_preview = 
#     book_content_list = 
#     book_price = 
#     book_release_date = 
    
#     book_review_count = 
#     book_rate = 
    
    print(book_title)
    print(book_test)
    print(book_find_all)
    print(data)

# %%
pick_books_info(35835750619)
# Out:
# 천 원을 경영하라
# 쌤앤파커스
# <div class="bookBasicInfo_info_detail__I0Fx5">경영전략/혁신</div>
# <!DOCTYPE html>
# ...

# %%
# 이 태그중에 class 명이 asideBoxRank인 html요소들을 가져옴
print("==========webtoonBox==========")
webtoonBox = soup.find("ol", attrs={"class" : "asideBoxRank"})
print(webtoonBox)

#추출한 html 요소들 중 a태그에 해당되는 내용을 전부 가져옴
print("==========webtoons==========")
webtoons = webtoonBox.find_all('a')
print(webtoons)

# %%
<span class="bookTitle_sub_title__B0uMS">국민가게 다이소 창업주 박정부 회장의 본질 경영</span>
