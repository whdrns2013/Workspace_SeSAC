# %% [markdown]
# # 음 만들어보기

# %%
# pip install soundfile
import numpy as np
import IPython.display as ipd
import matplotlib.pyplot as plt
import soundfile

# %% [markdown]
# ## IPython.display

# %%
sr = 16000 # sampling rate
f = 660    # 주파수
T = 2.0    # running time
           ## 1초에 16000개, 총 2초면 32000개 sample 존재
amp = 1.0
    
t = np.linspace(0, T, int(T*sr))    # 32000개의 신호 제작
y = amp * np.sin(2 * np.pi * f * t) # 주파수 적용한 신호

ipd.Audio(y, rate = sr)             # 오디오 재생
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 도레미파솔라시도

# %%
# 주파수 정의

pitch_do = 261.6256
pitch_re = 293.6648
pitch_mi = 329.6276
pitch_fa = 349.2282
pitch_sol = 391.9954
pitch_la = 440.0000
pitch_ti = 493.883
pitch_none = 0.0

# %% [markdown]
# ![image.png](attachment:989807e8-66b4-43f8-aeee-6f229f874127.png)

# %% [markdown]
# ## 화음 만들기

# %%
# 화음 만들기

sr = 16000 # sampling rate
T = 2.0    # running time
           ## 1초에 16000개, 총 2초면 32000개 sample 존재
amp = 1.0
    
t = np.linspace(0, T, int(T*sr))    # 32000개의 신호 제작

y_do = amp * np.sin(2 * np.pi * pitch_do * t)   # 주파수 적용한 신호
y_re = amp * np.sin(2 * np.pi * pitch_re * t)   # 주파수 적용한 신호
y_mi = amp * np.sin(2 * np.pi * pitch_mi * t)   # 주파수 적용한 신호
y_fa = amp * np.sin(2 * np.pi * pitch_fa * t)   # 주파수 적용한 신호
y_sol = amp * np.sin(2 * np.pi * pitch_sol * t) # 주파수 적용한 신호
y_la = amp * np.sin(2 * np.pi * pitch_la * t)   # 주파수 적용한 신호
y_ti = amp * np.sin(2 * np.pi * pitch_ti * t)   # 주파수 적용한 신호

C_maj_7_chord = y_do + y_mi + y_sol + y_ti

# 파장 살펴보기
plt.plot(t, C_maj_7_chord)
plt.show()

# 오디오 재생
ipd.Audio(C_maj_7_chord , rate = sr)             # 오디오 재생
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 노래 만들기

# %%
# 노래 만들기 : 도레미송

sr = 16000 # sampling rate
T = 0.5    # running time
           ## 1초에 16000개, 총 2초면 32000개 sample 존재
amp = 1.0
    
t = np.linspace(0, T, int(T*sr))    # 32000개의 신호 제작

y_do = amp * np.sin(2 * np.pi * pitch_do * t)   # 주파수 적용한 신호
y_re = amp * np.sin(2 * np.pi * pitch_re * t)   # 주파수 적용한 신호

T = 0.4
t = np.linspace(0, T, int(T*sr))    # 32000개의 신호 제작

y_mi = amp * np.sin(2 * np.pi * pitch_mi * t)   # 주파수 적용한 신호
y_fa = amp * np.sin(2 * np.pi * pitch_fa * t)   # 주파수 적용한 신호
y_sol = amp * np.sin(2 * np.pi * pitch_sol * t) # 주파수 적용한 신호
y_la = amp * np.sin(2 * np.pi * pitch_la * t)   # 주파수 적용한 신호
y_ti = amp * np.sin(2 * np.pi * pitch_ti * t)   # 주파수 적용한 신호

T = 0.1
t = np.linspace(0, T, int(T*sr))    # 32000개의 신호 제작
y_none = np.linspace(0, T, int(T*sr))

y = np.append(y_do, y_mi, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_mi, axis = 0)
y = np.append(y, y_mi, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_mi, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_sol, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_sol, axis = 0)
y = np.append(y, y_sol, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_re, axis = 0)
y = np.append(y, y_fa, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_fa, axis = 0)
y = np.append(y, y_fa, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_la, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_ti, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_ti, axis = 0)
y = np.append(y, y_ti, axis = 0)
y = np.append(y, y_none, axis = 0)
y = np.append(y, y_none, axis = 0)

# 파장 살펴보기
t = np.linspace(0, 8.1, int(8.1*sr))
plt.plot(t, y)
plt.show()

# 오디오 재생
ipd.Audio(y , rate = sr)             # 오디오 재생
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 노래 만들기 : 도레미송

sr = 16000 # sampling rate
T = 0.5    # running time
amp = 1.0
t = np.linspace(0, T, int(T*sr))    # 32000개의 신호 제작

y_do = amp * np.sin(2 * np.pi * pitch_do * t)   # 주파수 적용한 신호
y_re = amp * np.sin(2 * np.pi * pitch_re * t)   # 주파수 적용한 신호
y_mi = amp * np.sin(2 * np.pi * pitch_mi * t)   # 주파수 적용한 신호
y_fa = amp * np.sin(2 * np.pi * pitch_fa * t)   # 주파수 적용한 신호
y_sol = amp * np.sin(2 * np.pi * pitch_sol * t) # 주파수 적용한 신호
y_la = amp * np.sin(2 * np.pi * pitch_la * t)   # 주파수 적용한 신호
y_ti = amp * np.sin(2 * np.pi * pitch_ti * t)   # 주파수 적용한 신호

T = 0.1
t = np.linspace(0, T, int(T*sr))    # 32000개의 신호 제작
y_none = amp * np.sin(2 * np.pi * pitch_none * t)


y = np.append(y_sol, y_sol, axis = 0)
y = np.append(y, y_la, axis = 0)
y = np.append(y, y_la, axis = 0)
y = np.append(y, y_sol, axis = 0)
y = np.append(y, y_sol, axis = 0)
y = np.append(y, y_mi, axis = 0)
y = np.append(y, y_mi, axis = 0)
y = np.append(y, y_sol, axis = 0)
y = np.append(y, y_sol, axis = 0)
y = np.append(y, y_mi, axis = 0)
y = np.append(y, y_mi, axis = 0)
y = np.append(y, y_re, axis = 0)

# 저장
soundfile.write('schoolbell_plane.wav', y, sr, format='WAV')

# 오디오 재생
ipd.Audio(y , rate = sr)             # 오디오 재생
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 노래 만들기 : 학교종이땡땡땡 - 화음

sr = 16000 # sampling rate
T = 0.5    # running time
amp = 1.0
t = np.linspace(0, T, int(T*sr))    # 32000개의 신호 제작

y_do = amp * np.sin(2 * np.pi * pitch_do * t)   # 주파수 적용한 신호
y_re = amp * np.sin(2 * np.pi * pitch_re * t)   # 주파수 적용한 신호
y_mi = amp * np.sin(2 * np.pi * pitch_mi * t)   # 주파수 적용한 신호
y_fa = amp * np.sin(2 * np.pi * pitch_fa * t)   # 주파수 적용한 신호
y_sol = amp * np.sin(2 * np.pi * pitch_sol * t) # 주파수 적용한 신호
y_la = amp * np.sin(2 * np.pi * pitch_la * t)   # 주파수 적용한 신호
y_ti = amp * np.sin(2 * np.pi * pitch_ti * t)   # 주파수 적용한 신호

C_maj = (y_do + y_mi + y_sol) * 0.7
C_maj_7 = (y_do + y_mi + y_ti) * 0.7
Am = (y_la + y_do + y_mi) * 0.7
F_maj = (y_do + y_fa + y_la) * 0.7
G_maj = (y_re + y_sol + y_ti) * 0.7
G_maj_7 = (y_do + y_sol + y_ti) * 0.7


T = 0.1
t = np.linspace(0, T, int(T*sr))    # 32000개의 신호 제작
y_none = amp * np.sin(2 * np.pi * pitch_none * t)


y = np.append(C_maj, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, F_maj + (y_la*1.5), axis = 0)
y = np.append(y, F_maj +  (y_la*1.5), axis = 0)
y = np.append(y, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, C_maj + (y_mi*1.5), axis = 0)
y = np.append(y, C_maj , axis = 0)
y = np.append(y, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, C_maj + (y_mi*1.5), axis = 0)
y = np.append(y, C_maj + (y_mi*1.5), axis = 0)
y = np.append(y, G_maj + (y_re*1.5), axis = 0)
y = np.append(y, G_maj + (y_re*1.5), axis = 0)
y = np.append(y, G_maj + (y_re*1.5), axis = 0)
y = np.append(y, G_maj, axis = 0)
y = np.append(y, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, F_maj + (y_la*1.5), axis = 0)
y = np.append(y, F_maj +  (y_la*1.5), axis = 0)
y = np.append(y, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, C_maj + (y_mi*1.5), axis = 0)
y = np.append(y, C_maj , axis = 0)
y = np.append(y, C_maj + (y_sol*1.5), axis = 0)
y = np.append(y, C_maj + (y_mi*1.5), axis = 0)
y = np.append(y, G_maj_7 + (y_re*1.5), axis = 0)
y = np.append(y, G_maj_7 + (y_mi*1.5), axis = 0)
y = np.append(y, C_maj + (y_do*1.5), axis = 0)
y = np.append(y, C_maj + (y_do*1.5), axis = 0)



# 오디오 재생
ipd.Audio(y , rate = sr)             # 오디오 재생
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 사운드파일 저장과 읽기(불러오기)

# %% [markdown]
# ## 사운드파일 저장

# %%
# pip install soundfile
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import soundfile
soundfile.write("schoolbell.wav", y, sr, format="WAV")
soundfile.write("schoolbell_wrong.wav", y, int(sr/2), format="WAV") # 샘플링레이트 잘못 맞춤

# %% [markdown]
# ## 사운드파일 읽기

# %%
sound_contents, file_sampling_rate = soundfile.read('schoolbell.wav')
# soundfile.read -> 콘텐츠(음원 데이터), 샘플링레이트를 반환한다.

# %%
ipd.Audio(sound_contents, rate = file_sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
