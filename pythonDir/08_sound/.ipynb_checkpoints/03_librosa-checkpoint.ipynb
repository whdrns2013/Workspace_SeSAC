# %% [markdown]
# # 숙제

# %%
* 멜스펙트럼이 뭐야  
* 그래서 지금 뭘 하는거야  
* FFT가 뭐야

# %% [markdown]
# # Librosa

# %% [markdown]
# Librosa는 realtime으로 볼 수 있다.
# 반면 plt로 하면 realtime으로는 볼 수 없고, sample 개수가 x축에 그려진다.

# %% [markdown]
# ## Librosa로 그려보기

# %%
# pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: soundfile>=0.10.2 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from librosa) (0.11.0)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 20.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting numba>=0.45.1
#   Downloading numba-0.56.4-cp38-cp38-macosx_11_0_arm64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.7 MB/s eta 0:00:00a 0:00:01
# Collecting resampy>=0.2.2
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 25.4 MB/s eta 0:00:00a 0:00:01
# Collecting pooch>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.14 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: scipy>=1.2.0 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from librosa) (1.9.3)
# Requirement already satisfied: numpy>=1.17.0 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from librosa) (1.24.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.0.10 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from librosa) (22.0)
# Requirement already satisfied: setuptools in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from numba>=0.45.1->librosa) (65.6.3)
# Collecting numpy>=1.17.0
#   Downloading numpy-1.23.5-cp38-cp38-macosx_11_0_arm64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 25.9 MB/s eta 0:00:0000:0100:01
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp38-cp38-macosx_11_0_arm64.whl (23.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 24.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: importlib-metadata in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from numba>=0.45.1->librosa) (5.2.0)
# Collecting appdirs>=1.3.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests>=2.19.0 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from pooch>=1.0->librosa) (2.28.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.12.7)
# Requirement already satisfied: zipp>=0.5 in /Users/jongya/miniforge3/envs/jh/lib/python3.8/site-packages (from importlib-metadata->numba>=0.45.1->librosa) (3.11.0)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23704 sha256=d34f51727df42678b41b3da08db745e0b0af15fc9db99af63a098ec83a6cbc97
#   Stored in directory: /Users/jongya/Library/Caches/pip/wheels/74/25/48/ad94b69151b78e9aeba6850da119f04eda1c811d22fcf4b32d
# Successfully built audioread
# Installing collected packages: appdirs, numpy, llvmlite, audioread, pooch, numba, resampy, librosa
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.0
#     Uninstalling numpy-1.24.0:
#       Successfully uninstalled numpy-1.24.0
# Successfully installed appdirs-1.4.4 audioread-3.0.0 librosa-0.9.2 llvmlite-0.39.1 numba-0.56.4 numpy-1.23.5 pooch-1.6.0 resampy-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import librosa.display
import soundfile
import numpy as np
import IPython.display

# %%
sound_contents, file_sampling_rate = soundfile.read('schoolbell_plane.wav')

# %%
plt.figure(figsize = (14, 5))
librosa.display.waveshow(sound_contents[:100], sr = file_sampling_rate)

# %% [markdown]
# ## 1사이클 그려보기

# %%
# 주파수 정의

pitch_do = 261.6256
pitch_re = 293.6648
pitch_mi = 329.6276
pitch_fa = 349.2282
pitch_sol = 391.9954
pitch_la = 440.0000
pitch_ti = 493.883
pitch_none = 0.0

# %%
sr = 16000 # sampling rate
T = 2.0    # running time
           ## 1초에 16000개, 총 2초면 32000개 sample 존재
amp = 1.0
t = np.linspace(0, T, int(T*sr))    # 32000개의 신호 제작

y_do = amp * np.sin(2 * np.pi * pitch_do * t)   # 주파수 적용한 신호
y_re = amp * np.sin(2 * np.pi * pitch_re * t)   # 주파수 적용한 신호
y_mi = amp * np.sin(2 * np.pi * pitch_mi * t)   # 주파수 적용한 신호
y_fa = amp * np.sin(2 * np.pi * pitch_fa * t)   # 주파수 적용한 신호
y_sol = amp * np.sin(2 * np.pi * pitch_sol * t) # 주파수 적용한 신호
y_la = amp * np.sin(2 * np.pi * pitch_la * t)   # 주파수 적용한 신호
y_ti = amp * np.sin(2 * np.pi * pitch_ti * t)   # 주파수 적용한 신호

# %%
# 한 주기만 보기
a_cycle_time = int(file_sampling_rate/pitch_sol) + 1
librosa.display.waveshow(sound_contents[:a_cycle_time], sr = file_sampling_rate)

# %% [markdown]
# ## matplotlib으로 그려보면?

# %%
plt.plot(sound_contents[:a_cycle_time], "o-")
plt.show()

# %% [markdown]
# ## FFT

# %%
X = np.fft.fft(sound_contents[:a_cycle_time]*10) # 10ms
mag = np.abs(X)                                  # magnitude : 진폭
f = np.linspace(0, file_sampling_rate, len(mag))
f_left = f[:int(len(mag)/2)]                     # 주파수는 대칭임. 그러므로 반만 fft해도 됨
spectrum_X = mag[:int(len(mag)/2)]               # 주파수 스펙트럼

plt.stem(f_left, spectrum_X, 'o-')               # stem : 일반적인 선형 그래프가 아닌,
plt.xlabel('frequency')
plt.ylabel('magnitude')
plt.title('spectrum')
plt.show()

# %% [markdown]
# 보면, 소리가 있는 sol 주파수 뿐만 아니라, 그 다음 주파수도 약간 값이 있다.
# 이는, 자연스러운 현상으로 '배음' 현상인 것.

# %%
spectrum_X
# Out:
# array([1.23596191e-01, 2.04523227e+02, 1.26671764e+00, 7.14970734e-01,
#        5.11691226e-01, 4.02647597e-01, 3.35579592e-01, 2.88834224e-01,
#        2.55350541e-01, 2.30092000e-01, 2.11042737e-01, 1.95020868e-01,
#        1.82746535e-01, 1.72020343e-01, 1.65670920e-01, 1.58567331e-01,
#        1.53662277e-01, 1.50407379e-01, 1.47889283e-01, 1.45917565e-01])

# %% [markdown]
# ## librosa.stft, display.specshow

# %%
X = librosa.stft(sound_contents) # short time fourier transform
# 음성에서 short time은 일반적으로 10ms을 말한다.  

Xdb = librosa.amplitude_to_db(abs(X))
# amplitude : 진폭
# db : 데시벨

librosa.display.specshow(Xdb, sr=file_sampling_rate, x_axis='time', y_axis='hz')

# %%
librosa.display.specshow(Xdb, sr=file_sampling_rate, x_axis='time', y_axis='log')
# log scale 을 사용하면,
# 아래위 남는 여백 없이, 주요 부분들에 집중해서 볼 수 있음

# %%
X = librosa.stft(sound_contents) # short time fourier transform
# 음성에서 short time은 일반적으로 10ms을 말한다.  

Xdb = librosa.amplitude_to_db(abs(X))
# amplitude : 진폭
# db : 데시벨
librosa.display.specshow(Xdb, sr=file_sampling_rate, x_axis='time', y_axis='log')
plt.title('Log freq power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.show()

# db별로 그릴 수 있음
# -> 근데 이는 '기준'이 없음

# %%
X = librosa.stft(sound_contents) # short time fourier transform
# 음성에서 short time은 일반적으로 10ms을 말한다.  

Xdb = librosa.amplitude_to_db(abs(X), ref=np.max) # 기준을 잡아줌 : max인 0db부터 아래로 내려가게끔
# 0db를 기준으로 삼는 이유 : 위로 올라가면 소리가 깨질 수 있음.
# 제일 작은 소리를 0으로 두면, 소리가 무한으로 커지면 그것을 재현할 수 없음
# 그러나 제일 큰 소리를 0으로 기준을 두면, 그보다 작은 소리는 마이너스 하면 되므로 재현 가능

# amplitude : 진폭
# db : 데시벨
librosa.display.specshow(Xdb, sr=file_sampling_rate, x_axis='time', y_axis='log')
plt.title('Log freq power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.show()

# %%
X = librosa.stft(sound_contents) # short time fourier transform


Xdb = librosa.amplitude_to_db(abs(X), ref=np.max) # 기준을 잡아줌 : max인 0db부터 아래로 내려가게끔

librosa.display.specshow(Xdb, sr=file_sampling_rate, x_axis='time', y_axis='linear')
plt.title('Linear freq power spectrogram')
# linear로 해보기
plt.colorbar(format='%+2.0f dB')
plt.show()

# %% [markdown]
# ## MFCC (melspectrogram)

# %% [markdown]
# * 음역대를 n개로 나누어 데이터를 표시화는 것이 멜스펙트럼
# * 사람의 청각세포의 개수는 한정이 되어있고, 느낄 수 있는 음간 차이는 한계가 있으므로
# * 사람이 들을 수 있는 음차의 한계에 맞춰 음역대를 맞추면, 빠른 연산과 충분한 성능이 나올 것이라는 것
# * 멜스펙트럼의 개수가 너무 많으면(세분화하면) 연산량이 많아지고
# * 멜스펙트럼의 개수가 너무 적으면(대략 잡으면) 연산량은 적어지나, 제대로된 분류가 불가

# %%
D = abs(librosa.stft(sound_contents)) # 데이터 : 절대값 바로 먹임
mel_spec = librosa.feature.melspectrogram(S=D, n_mels=1028) # melspectrogram 구하기
# signal = D / n_mels : n_mels레벨을 지정 : Hz 구간을 몇 개로 나눌지 정의
# 이 부분을 너무 약하게(적게) 잡으면 분석이 잘 안될 것이고 (장르구분 등에서)
# 이 부분을 너무 강하게(많이) 잡으면 분석하는 데 시간이 오래 걸리고...
# 그리고, 우리 귀는 엄청 자세하게 듣지는 못하므로 (청세포의 개수는 정해져있음),  
# 그에 충분한 숫자 만큼만을 지정하면 되지 않느냐 => 라는 것에서 시작된 것이 멜스펙트럼

mel_db = librosa.amplitude_to_db(mel_spec, ref=0.000001) # 0.000001

librosa.display.specshow(mel_db, sr=file_sampling_rate, x_axis='time', y_axis='mel') # y_axis 바뀜
plt.title('Log freq power spectrogram')

plt.colorbar(format='%+2.0f dB')
plt.show()

# %%
D = abs(librosa.stft(sound_contents)) # 데이터 : 절대값 바로 먹임
mel_spec = librosa.feature.melspectrogram(S=D, n_mels=20) # melspectrogram 구하기
# signal = D / n_mels : n_mels레벨을 지정 : Hz 구간을 몇 개로 나눌지 정의
# 이 부분을 너무 약하게(적게) 잡으면 분석이 잘 안될 것이고 (장르구분 등에서)
# 이 부분을 너무 강하게(많이) 잡으면 분석하는 데 시간이 오래 걸리고...
# 그리고, 우리 귀는 엄청 자세하게 듣지는 못하므로 (청세포의 개수는 정해져있음),  
# 그에 충분한 숫자 만큼만을 지정하면 되지 않느냐 => 라는 것에서 시작된 것이 멜스펙트럼


mel_db = librosa.amplitude_to_db(mel_spec, ref=0.000001) # 0.000001

librosa.display.specshow(mel_db, sr=file_sampling_rate, x_axis='time', y_axis='mel') # y_axis 바뀜
plt.title('Log freq power spectrogram')

plt.colorbar(format='%+2.0f dB')
plt.show()

# %% [markdown]
# # 실습

# %%
sound_content, sample_rate = soundfile.read('aeiowoo.wav')

# %%
# 전체
plt.figure(figsize = (14, 5))
librosa.display.waveshow(sound_content, sr = sample_rate)

# %%
# 아~ 부분 패턴
plt.figure(figsize = (14, 5))
start_sec = 0.55
librosa.display.waveshow(sound_content[int(start_sec*44100):int(start_sec*44100+3000)], sr = sample_rate)

# %%
# 에~ 부분 패턴
plt.figure(figsize = (14, 5))
start_sec = 5.5
librosa.display.waveshow(sound_content[int(start_sec*44100):int(start_sec*44100+3000)], sr = sample_rate)

# %%
# 이~ 부분 패턴
plt.figure(figsize = (14, 5))
start_sec = 11
librosa.display.waveshow(sound_content[int(start_sec*44100):int(start_sec*44100+3000)], sr = sample_rate)

# %%
# 오~ 부분 패턴
plt.figure(figsize = (14, 5))
start_sec = 16
librosa.display.waveshow(sound_content[int(start_sec*44100):int(start_sec*44100+3000)], sr = sample_rate)

# %%
# 우~ 부분 패턴
plt.figure(figsize = (14, 5))
start_sec = 21
librosa.display.waveshow(sound_content[int(start_sec*44100):int(start_sec*44100+3000)], sr = sample_rate)
