# %% [markdown]
# # ????
#
# ![image.png](attachment:359e9d8c-a2bb-4d2e-89a4-cbac29428ff0.png)
#
# 잔차연결을 통해 (원본 -> Add&Norm)
# (1) 원본의 데이터도 가져오고
# (2) 처리를 거치는 데이터도 가져오고
# 그래서, 원본을 잃지 않는다.
#
#
# 예를 들어, 이미지 처리에서 CNN을 통해 계속 처리하면...
# 이미지의 원본은 알아볼 수도 없이 뭉개져 있을 것이다.
# 그러면 과연 그게 좋은 것인가?
# 그렇지 않다. 원본에 대한 기억도 있어야 함.
# 그래서 이미지처리에서 나온 모델이 VGG16..
#
# # Multi Attention
#
# ![image.png](attachment:f512e329-d548-41e0-8412-845cd9cee0cf.png)
#
# 병렬처리를 통해 한 번에 빻!

# %% [markdown]
# # 알고리즘 복잡도
#
# ![image.png](attachment:dbdf8d60-aa04-4b48-894a-136b81dc2184.png)
#
# O2n 으로 푸는 것을 -> On으로 가는 게 더 적게 리소스가 쓰인다.
# O(1)이면 제일 좋고

# %%
# absolute index
"나는1 너를2 사랑한다3"
"말하자면1 나는2 너를3 사랑한다는4 말이야5"

# relative index
# 인덱스가 겹치게 된다... 이것을 해결하기 위해
# 상대적으로 index를 하는 방법을 고민했고, sin과 cos를 이용한 방법이 등장했다.
        "나는1 너를2 사랑한다3"
"말하자면1 나는2 너를3 사랑한다는4 말이야5"

# %% [markdown]
# ![image.png](attachment:8b1fb41d-e875-4e95-8d3f-8af9d3d5c945.png)
#
# (1) sin과 cos는 본질적으로 동일한 파형이며
# (2) 양 극단이 모두 무한인 함수이다.
#
# 이에 따라 sin과 cos은 좌우 시프트만 하면 겹치게 되므로
#
# (3) 그리고 말하자면 bias가 다르므로...??
# 어떻게 이걸 했다는 겨

# %% [markdown]
# # Transformer

# %%
a = 'abcd'
b = 'cd'
c = 'ef'

a.replace(c,'')
# Out:
# 'abcd'

# %%
li = ["aya", "ye", "woo", "ma"]

# %%
ans = ["aya", "yee", "u", "maa", "wyeoo"]
# Out:
# 2

# %%
a = 'ayaye'
b = 'ye'
d = 'aya'
c = a.replace(b, '1')
c = c.replace(d, '1')

int(a)

try list.append(int(a))

except
pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 7
#       4 c = a.replace(b, '1')
#       5 c = c.replace(d, '1')
# ----> 7 int(a)
#
# ValueError: invalid literal for int() with base 10: 'ayaye'
